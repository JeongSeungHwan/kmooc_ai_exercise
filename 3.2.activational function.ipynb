# %% [markdown]
# ### 활성화 함수

# %%
def activate(z) :
    """"returns 32 if z < 32"""
    if z < 32 :
        z = 32
    return z

# %%
def C2F(C):
    """converts Celcius to Fahrenheit"""
    F = 9/5.0 * C + 32
    return activate(F)

# %%
test_c = [-20,-10,0,36.5,40,50,100]
test_f = [ C2F(c) for c in test_c ]
print(test_f)
# Out:
# [32, 32, 32.0, 97.7, 104.0, 122.0, 212.0]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Plotting the simple neuron
x = np.arange(-100,100,.1)
y = [C2F(ix) for ix in x]
plt.figure()
plt.plot(x, y)
plt.axis([-20, 50, 0, 150])
plt.xlabel('Celcius')
plt.ylabel('Fahrenheit')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-75f062cc7620> in <module>
#       5 # Plotting the simple neuron
#       6 x = np.arange(-100,100,.1)
# ----> 7 y = [C2F(ix) for ix in x]
#       8 plt.figure()
#       9 plt.plot(x, y)
#
# <ipython-input-3-75f062cc7620> in <listcomp>(.0)
#       5 # Plotting the simple neuron
#       6 x = np.arange(-100,100,.1)
# ----> 7 y = [C2F(ix) for ix in x]
#       8 plt.figure()
#       9 plt.plot(x, y)
#
# NameError: name 'C2F' is not defined

# %%
def step(x):
    return (x > 0) * 1

x = np.arange(-3.0, 3.0, 0.001)
y = step(x)
plt.plot(x, y)
plt.axvline(0, color='black', linewidth=0.5)
plt.ylim(-0.1, 1.1)
plt.xlabel('x')
plt.ylabel('h(x)')
plt.show()

# %%
def sig(x):
    return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

# %%
sig(3)
# Out:
# 0.9950547536867306
